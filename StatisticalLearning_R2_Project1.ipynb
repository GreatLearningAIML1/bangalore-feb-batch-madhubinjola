# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Laliga.csv",na_values = '-')

# %%
# df.tail(n=10)

# %%
#df.info()

# %%
Debut_split = df.Debut.str.split('-')

# %%
print(Debut_split.head(5))
# Out:
# 0        [1929]
# 1        [1929]
# 2        [1929]
# 3    [1931, 32]
# 4        [1929]
# Name: Debut, dtype: object

# %%
Debut_start = Debut_split.str.get(0)

# %%
#Debut_end = Debut_split.str.get(1)

# %%
df['Debut_start'] = Debut_start

# %%
df['Debut_end'] = Debut_end

# %%
df.drop(df[["Debut"]], axis = 1, inplace=True)

# %%
df.dtypes
# Out:
# Pos                int64
# Team              object
# Seasons            int64
# Points           float64
# GamesPlayed      float64
# GamesWon         float64
# GamesDrawn       float64
# GamesLost        float64
# GoalsFor         float64
# GoalsAgainst     float64
# Champion         float64
# Runner-up        float64
# Third            float64
# Fourth           float64
# Fifth            float64
# Sixth            float64
# T                float64
# Since/LastApp     object
# BestPosition       int64
# Debut_start       object
# Debut_end         object
# dtype: object

# %%
df["Debut_start"] = pd.to_numeric(df["Debut_start"])

# %%
df.dtypes
# Out:
# Pos                int64
# Team              object
# Seasons            int64
# Points           float64
# GamesPlayed      float64
# GamesWon         float64
# GamesDrawn       float64
# GamesLost        float64
# GoalsFor         float64
# GoalsAgainst     float64
# Champion         float64
# Runner-up        float64
# Third            float64
# Fourth           float64
# Fifth            float64
# Sixth            float64
# T                float64
# Since/LastApp     object
# BestPosition       int64
# Debut_start        int64
# Debut_end         object
# dtype: object

# %%
df_subset = df[(df['Debut_start'] > 1929) & (df['Debut_start'] < 1981)]

# %%
df_subset
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 3     4             Valencia       82  3386.0       2664.0    1187.0
# 5     6              Sevilla       73  2819.0       2408.0     990.0
# 8     9             Zaragoza       58  2109.0       1986.0     698.0
# 9    10           Real Betis       51  1884.0       1728.0     606.0
# 10   11  Deportivo La Coruna       45  1814.0       1530.0     563.0
# 11   12           Celta Vigo       51  1789.0       1698.0     586.0
# 12   13           Valladolid       42  1471.0       1466.0     463.0
# 14   15       Sporting Gijon       43  1389.0       1458.0     471.0
# 15   16              Osasuna       37  1351.0       1318.0     426.0
# 16   17               Malaga       36  1314.0       1255.0     390.0
# 17   18               Oviedo       38  1174.0       1192.0     408.0
# 18   19             Mallorca       27  1148.0        988.0     333.0
# 19   20           Las Palmas       33  1020.0       1096.0     367.0
# ...

# %%
#df_final = df.groupby()

# %%
print(df["Points"].head(10))
# Out:
# 0    4385.0
# 1    4262.0
# 2    3442.0
# 3    3386.0
# 4    3368.0
# 5    2819.0
# 6    2792.0
# 7    2573.0
# 8    2109.0
# 9    1884.0
# Name: Points, dtype: float64

# %%
df.sort_values(by = ['Points'], ascending = False, inplace = True)

# %%
print(df['Team'].head(5))
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
df.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Since/LastApp',
#        'BestPosition', 'Debut_start', 'Debut_end'],
#       dtype='object')

# %%
def Goal_diff_count(x,y):
    return (x-y)

df['Goal_diff_count'] = Goal_diff_count(df['GoalsFor'], df['GoalsAgainst'])

# %%
print(df['Goal_diff_count'].head())
# Out:
# 0    2807.0
# 1    2786.0
# 2    1225.0
# 3     929.0
# 4     931.0
# Name: Goal_diff_count, dtype: float64

# %%
print(df[df['Goal_diff_count'] == df['Goal_diff_count'].max()])
# Out:
#    Pos         Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1  Real Madrid       86  4385.0       2762.0    1647.0       552.0
#
#    GamesLost  GoalsFor  GoalsAgainst       ...         Third  Fourth  Fifth  \
# 0      563.0    5947.0        3140.0       ...           8.0     8.0    3.0
#
#    Sixth     T  Since/LastApp  BestPosition Debut_start  Debut_end  \
# 0    4.0  79.0           1929             1        1929        NaN
#
#    Goal_diff_count
# 0           2807.0
#
# [1 rows x 22 columns]

# %%
print(df[df['Goal_diff_count'] == df['Goal_diff_count'].min()])
# Out:
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 13   14  Racing Santander       44  1416.0       1428.0     453.0       336.0
#
#     GamesLost  GoalsFor  GoalsAgainst       ...         Third  Fourth  Fifth  \
# 13      639.0    1843.0        2368.0       ...           1.0     2.0    NaN
#
#     Sixth    T  Since/LastApp  BestPosition Debut_start  Debut_end  \
# 13    1.0  5.0        2011-12             2        1929        NaN
#
#     Goal_diff_count
# 13           -525.0
#
# [1 rows x 22 columns]

# %%
# new column with name “Winning Percent”
df['Winning percent'] = (df['GamesWon'] / df['GamesPlayed'])*100

# %%
# top 5 teams which has the highest Winning percentage
df.sort_values(by = ['Winning percent'], ascending = False, inplace = True)

# %%
print(df['Team'].head(5))
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
# Group teams based on their “Best position” and print the sum of their points for all positions
print(df.groupby('BestPosition')['Points'].sum())
# Out:
# BestPosition
# 1     27933.0
# 2      6904.0
# 3      5221.0
# 4      6563.0
# 5      1884.0
# 6      2113.0
# 7      1186.0
# 8      1134.0
# 9        96.0
# 10      450.0
# 11      445.0
# 12      511.0
# 14       71.0
# 15       14.0
# 16       81.0
# 17      266.0
# 19       81.0
# 20       34.0
# Name: Points, dtype: float64
